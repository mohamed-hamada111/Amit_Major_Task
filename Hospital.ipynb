# %%
import import_ipynb
import Department
import patient_class
import staff
from Department import Department
from patient_class import Patient
from staff import Staff

# %%
class Hospital:
    def __init__(self, name, location):
        self.name = name
        self.location = location
        self.departments = []  # contains departments

    def add_department(self, department):
        self.departments.append(department)
        print(f"Department '{department.name}' added to {self.name}.")

    def view_info(self):
        print(f"Hospital Name: {self.name}")
        print(f"Location: {self.location}")
        print("Departments:")
        for dept in self.departments:
            print(f"- {dept.name}")

# %% [markdown]
# ## Testing
# ### for testing the required output

# %%
hospital = Hospital('Medical Hospital','Cairo')
dep =Department('Cardiology')
patient = Patient('Alice' ,30,'No known allergies')
staff = Staff('Dr. Smith' ,45,'Cardiologist')
hospital.add_department(dep)
dep.add_patient(patient)
dep.add_staff(staff)
print(patient.view_record())
print(staff.view_info())
# Out:
# Department 'Cardiology' added to Medical Hospital.
# Patient Alice added to Cardiology department
# Staff Dr. Smith added to Cardiology department
# Medical Record for Alice: No known allergies
# Name: Dr. Smith, Age: 45, Position: Cardiologist
