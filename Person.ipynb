# %% [markdown]
# # Person Class

# %% [markdown]
# I created a Person class to serve as the base class for a Patient class

# %%
class Person:
    """
    this is a class person in a Hospital system.

    This class stores common information that
    shared by all people such as name and age.
    It can be inherited by other classes like Patient or Staff.
    """
    def __init__(self, name, age):
        """
        Initializes a Person object.

        Parameters:
        name (str): The name of the person.
        age (int): The age of the person.
        """
        self.name = name
        self.age = age
#function to view info of person
    def view_info(self):
        """
        function to view info of person.

        Returns:
        str: A string that includes the person's name and age.
        """
        return f"Name: {self.name}, Age: {self.age}"
