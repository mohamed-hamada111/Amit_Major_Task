# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # patient

# %% [markdown]
# I created a Person class to serve as the base class for a Patient class

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
#function to view info of person
    def view_info(self):
        return f"Name: {self.name}, Age: {self.age}"

# %%
#create subclass Patient that inherits from Person
class Patient(Person):
    def __init__(self, name, age, medical_record):
       #call the constructor of the parent class Person
        super().__init__(name, age)
        #initialize medical_record attribute
        self.medical_record = medical_record
    def view_record(self):
       #FUNCTION TO VIEW MEDICAL RECORD OF PATIENT
        return f"Medical Record for {self.name}: {self.medical_record}"
#--- Testing the Classes ---
#Create an instance of Patient
patient1 = Patient("Ahmed", 30, "The patient has no allergies and a recorded history of flu")
#Try the inherited method from Person
print(patient1.view_info())  
#Try the method from Patient
print(patient1.view_record())
# Out:
# Name: Ahmed, Age: 30
# Medical Record for Ahmed: The patient has no allergies and a recorded history of flu
